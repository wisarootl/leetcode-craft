# %% [markdown]
# # 72. Edit Distance

# %% [markdown]
# https://leetcode.com/problems/edit-distance/

# %%
class Solution:
    # time = O(n * m)
    # space = O(min(n , m))
    # m = len(word1)
    # n = len(word2)

    def minDistance(self, word1: str, word2: str) -> int:
        m, n = len(word1), len(word2)

        prev_row = [j for j in range(n + 1)]
        curr_row = [0 for _ in range(n + 1)]

        for i in range(1, m + 1):
            curr_row[0] = i
            for j in range(1, n + 1):
                if word1[i - 1] == word2[j - 1]:
                    curr_row[j] = prev_row[j - 1]
                else:
                    curr_row[j] = 1 + min(
                        prev_row[j],  # Insert, Delete
                        curr_row[j - 1],  # Insert, Delete
                        prev_row[j - 1],  # Replace
                    )
            prev_row, curr_row = curr_row, prev_row

        return prev_row[n]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
word1 = "horse"
word2 = "ros"

expected = 3
output = Solution().minDistance(word1, word2)
print(output)
assert output == expected
# Out:
# 3

# %%
word1 = "intention"
word2 = "execution"

expected = 5
output = Solution().minDistance(word1, word2)
print(output)
assert output == expected
# Out:
# 5
